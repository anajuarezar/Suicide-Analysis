# %%
## Dependencies
import os
import pandas as pd

# %%
# Set CSV input file path
input_path = os.path.join('country_list.csv')
# Read CSV to DataFrame
df = pd.read_csv(input_path, encoding = "ISO-8859-1")
df
# Out:
#      Columna1                   World Bank          WHO  \
# 0         0.0                  Afghanistan  Afghanistan
# 1         1.0  Africa Eastern and Southern          NaN
# 2         2.0   Africa Western and Central          NaN
# 3         3.0                          NaN          NaN
# 4         4.0                      Albania      Albania
# ..        ...                          ...          ...
# 326       NaN                          NaN          NaN
# 327       NaN                          NaN          NaN
# 328       NaN                  Yemen, Rep.        Yemen
# 329       NaN                       Zambia       Zambia
# 330       NaN                     Zimbabwe     Zimbabwe
#
#               Our World in Data        ONU Dicc ISO-alpha3 code
# 0                   Afghanistan     Afghanistan             AFG
# 1                           NaN             NaN             NaN
# 2                           NaN             NaN             NaN
# ...

# %%
countries = df[["World Bank", "WHO", "Our World in Data", "ONU Dicc", "ISO-alpha3 code"]]
countries
# Out:
#                       World Bank          WHO           Our World in Data  \
# 0                    Afghanistan  Afghanistan                 Afghanistan
# 1    Africa Eastern and Southern          NaN                         NaN
# 2     Africa Western and Central          NaN                         NaN
# 3                            NaN          NaN                         NaN
# 4                        Albania      Albania                     Albania
# ..                           ...          ...                         ...
# 326                          NaN          NaN              Western Europe
# 327                          NaN          NaN  Western Sub-Saharan Africa
# 328                  Yemen, Rep.        Yemen                       Yemen
# 329                       Zambia       Zambia                      Zambia
# 330                     Zimbabwe     Zimbabwe                    Zimbabwe
#
#            ONU Dicc ISO-alpha3 code
# 0       Afghanistan             AFG
# ...

# %%
countries_df = countries.rename(columns={
                       "World Bank":"world_bank", 
                       "WHO":"who", 
                       "Our World in Data":"owid",
                       "ONU Dicc": "onu", 
                       "ISO-alpha3 code":"iso_country"})
countries_df
# Out:
#                       world_bank          who                        owid  \
# 0                    Afghanistan  Afghanistan                 Afghanistan
# 1    Africa Eastern and Southern          NaN                         NaN
# 2     Africa Western and Central          NaN                         NaN
# 3                            NaN          NaN                         NaN
# 4                        Albania      Albania                     Albania
# ..                           ...          ...                         ...
# 326                          NaN          NaN              Western Europe
# 327                          NaN          NaN  Western Sub-Saharan Africa
# 328                  Yemen, Rep.        Yemen                       Yemen
# 329                       Zambia       Zambia                      Zambia
# 330                     Zimbabwe     Zimbabwe                    Zimbabwe
#
#                 onu iso_country
# 0       Afghanistan         AFG
# ...

# %%
countries_df.to_csv("clean/extract_countries_all.csv", index=False)

# %%
countries_df.loc[countries_df['owid'] == 'Russia']
# Out:
#              world_bank                 who    owid                 onu  \
# 248  Russian Federation  Russian Federation  Russia  Russian Federation
#
#     iso_country
# 248         RUS
