# %%
## Dependencies
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## Suicide Rate of Change (pct_change)

# %%
## Set input file
filename = 'suicide_data_final.csv'
path = os.path.join('output', filename)

# %%
## Load CSV as DataFrame
df = pd.read_csv(path, low_memory=False)

# %%
df.head()
# Out:
#        country  year      country_year  suicide_rate_owid  \
# 0  Afghanistan  1990  Afghanistan-1990          10.318504
# 1  Afghanistan  1991  Afghanistan-1991          10.327010
# 2  Afghanistan  1992  Afghanistan-1992          10.271411
# 3  Afghanistan  1993  Afghanistan-1993          10.376123
# 4  Afghanistan  1994  Afghanistan-1994          10.575915
#
#    mental_substance_disorders  life_expectancy  birth_rate  death_rate  gdp  \
# 0                   17.553463           50.331      48.880      15.241  NaN
# 1                   17.837032           50.999      48.763      14.783  NaN
# 2                   18.092542           51.641      48.709      14.362  NaN
# 3                   18.294931           52.256      48.717      13.974  NaN
# 4                   18.428908           52.842      48.770      13.616  NaN
#
#    health_pct  population  unemployment
# 0         NaN  12412311.0           NaN
# 1         NaN  13299016.0         11.38
# 2         NaN  14485543.0         11.46
# 3         NaN  15816601.0         11.61
# 4         NaN  17075728.0         11.65

# %%
## Number of Countries & Shape
print("Countries:", df['country'].nunique())
print("Shape:", df.shape)
# Out:
# Countries: 188
# Shape: (5196, 12)

# %%
## Explore data
df.dtypes
# Out:
# country                        object
# year                            int64
# country_year                   object
# suicide_rate_owid             float64
# mental_substance_disorders    float64
# life_expectancy               float64
# birth_rate                    float64
# death_rate                    float64
# gdp                           float64
# health_pct                    float64
# population                    float64
# unemployment                  float64
# dtype: object

# %%
## Drop NaN
df = df.dropna()

## Number of Countries & Shape
print("Countries:", df['country'].nunique())
print("Shape:", df.shape)
# Out:
# Countries: 173
# Shape: (3068, 12)

# %%
## Drop Zeros
zero_loc = (df != 0).any(axis=1)
# zero_loc.value_counts()

df = df.loc[zero_loc]

## Number of Countries & Shape
print("Countries:", df['country'].nunique())
print("Shape:", df.shape)
# Out:
# Countries: 173
# Shape: (3068, 12)

# %%
df = df.sort_values(by=['country', 'year'])
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#        country  year      country_year  suicide_rate_owid  \
# 0  Afghanistan  2002  Afghanistan-2002          11.054472
# 1  Afghanistan  2003  Afghanistan-2003          10.931093
# 2  Afghanistan  2004  Afghanistan-2004          10.839790
# 3  Afghanistan  2005  Afghanistan-2005          10.655626
# 4  Afghanistan  2006  Afghanistan-2006          10.538475
#
#    mental_substance_disorders  life_expectancy  birth_rate  death_rate  \
# 0                   18.137951           56.784      46.901      11.048
# 1                   17.958849           57.271      46.231      10.704
# 2                   17.788825           57.772      45.507      10.356
# 3                   17.647911           58.290      44.723      10.003
# 4                   17.539914           58.826      43.870       9.645
#
#           gdp  health_pct  population  unemployment
# 0  179.426579    9.443390  22600774.0         11.68
# 1  190.683814    8.941258  23680871.0         11.68
# 2  211.382074    9.808474  24726689.0         11.61
# 3  242.031313    9.948290  25654274.0         11.52
# 4  263.733602   10.622766  26433058.0         11.34

# %%
df.columns
# Out:
# Index(['country', 'year', 'country_year', 'suicide_rate_owid',
#        'mental_substance_disorders', 'life_expectancy', 'birth_rate',
#        'death_rate', 'gdp', 'health_pct', 'population', 'unemployment'],
#       dtype='object')

# %%
## Select columns with data (target & features)
data_cols = ['suicide_rate_owid',
             'mental_substance_disorders',
             'life_expectancy',
             'birth_rate',
             'death_rate',
             'gdp',
             'health_pct',
             'population',
             'unemployment']

# %% [markdown]
# ## Pct_change by country

# %%
country_list = df['country'].unique()
len(country_list)
# Out:
# 173

# %%
## Create global DataFrame
roc_df = pd.DataFrame(columns=data_cols)

## ROC by country
for country in country_list:
    country_df = df.loc[df['country'] == country]
    country_roc = country_df[data_cols].pct_change().dropna()
    
    ## Append to global DataFrame
    roc_df = roc_df.append(country_roc, ignore_index=True)

# %%
## Global year-to-year rate of change (%)
roc_df
# Out:
#       suicide_rate_owid  mental_substance_disorders  life_expectancy  \
# 0             -0.011161                   -0.009874         0.008576
# 1             -0.008353                   -0.009467         0.008748
# 2             -0.016990                   -0.007921         0.008966
# 3             -0.010994                   -0.006120         0.009195
# 4             -0.013982                   -0.005450         0.009333
# ...                 ...                         ...              ...
# 2890          -0.033555                    0.000965         0.033889
# 2891          -0.026644                    0.001184         0.026592
# 2892          -0.014797                    0.001209         0.019243
# 2893          -0.013144                    0.001584         0.012766
# 2894          -0.016685                    0.001161         0.008591
#
#       birth_rate  death_rate       gdp  health_pct  population  unemployment
# 0      -0.014285   -0.031137  0.062740   -0.053173    0.047790      0.000000
# 1      -0.015660   -0.032511  0.108548    0.096990    0.044163     -0.005993
# 2      -0.017228   -0.034087  0.144995    0.014255    0.037514     -0.007752
# 3      -0.019073   -0.035789  0.089667    0.067798    0.030357     -0.015625
# 4      -0.021108   -0.037118  0.363850   -0.067599    0.025252     -0.014109
# ...          ...         ...       ...         ...         ...           ...
# 2890   -0.014438   -0.094206  0.095811    0.027723    0.017936      0.000000
# 2891   -0.022087   -0.082847  0.003425    0.143932    0.017702     -0.009294
# 2892   -0.028504   -0.065107  0.007090   -0.083784    0.016776     -0.007505
# 2893   -0.032871   -0.044621  0.013507    0.026242    0.015614     -0.009452
# 2894   -0.034445   -0.029206 -0.088027   -0.235086    0.014701     -0.017176
#
# [2895 rows x 9 columns]

# %%
## Shape & Summary
print("Shape:", roc_df.shape)
roc_df.describe()
# Out:
# Shape: (2895, 9)
#        suicide_rate_owid  mental_substance_disorders  life_expectancy  \
# count        2895.000000                 2895.000000      2895.000000
# mean           -0.010070                   -0.000695         0.005352
# std             0.029292                    0.001822         0.005952
# min            -0.169668                   -0.011381        -0.035607
# 25%            -0.022753                   -0.001430         0.002200
# 50%            -0.008738                   -0.000362         0.003879
# 75%             0.002169                    0.000322         0.006925
# max             0.413126                    0.007115         0.044550
#
#         birth_rate   death_rate          gdp   health_pct   population  \
# count  2895.000000  2895.000000  2895.000000  2895.000000  2895.000000
# mean     -0.009694    -0.009642     0.071781     0.015875     0.015406
# std       0.021610     0.023843     0.135828     0.109649     0.016162
# min      -0.138686    -0.133333    -0.640223    -0.443989    -0.037746
# 25%      -0.018552    -0.024093     0.005297    -0.030541     0.005205
# 50%      -0.011374    -0.008348     0.063201     0.006622     0.013557
# 75%      -0.002873     0.004373     0.138901     0.048805     0.024310
# max       0.144928     0.098361     1.884354     1.478131     0.191392
#
#        unemployment
# count   2895.000000
# mean       0.004385
# std        0.184757
# min       -0.805556
# 25%       -0.057515
# 50%       -0.006925
# 75%        0.037356
# max        5.812500

# %%
## Remove infinite values
roc_df.replace([np.inf, -np.inf], np.nan, inplace=True)
clean_df = roc_df.dropna()
clean_df
# Out:
#       suicide_rate_owid  mental_substance_disorders  life_expectancy  \
# 0             -0.011161                   -0.009874         0.008576
# 1             -0.008353                   -0.009467         0.008748
# 2             -0.016990                   -0.007921         0.008966
# 3             -0.010994                   -0.006120         0.009195
# 4             -0.013982                   -0.005450         0.009333
# ...                 ...                         ...              ...
# 2890          -0.033555                    0.000965         0.033889
# 2891          -0.026644                    0.001184         0.026592
# 2892          -0.014797                    0.001209         0.019243
# 2893          -0.013144                    0.001584         0.012766
# 2894          -0.016685                    0.001161         0.008591
#
#       birth_rate  death_rate       gdp  health_pct  population  unemployment
# 0      -0.014285   -0.031137  0.062740   -0.053173    0.047790      0.000000
# 1      -0.015660   -0.032511  0.108548    0.096990    0.044163     -0.005993
# 2      -0.017228   -0.034087  0.144995    0.014255    0.037514     -0.007752
# 3      -0.019073   -0.035789  0.089667    0.067798    0.030357     -0.015625
# 4      -0.021108   -0.037118  0.363850   -0.067599    0.025252     -0.014109
# ...          ...         ...       ...         ...         ...           ...
# 2890   -0.014438   -0.094206  0.095811    0.027723    0.017936      0.000000
# 2891   -0.022087   -0.082847  0.003425    0.143932    0.017702     -0.009294
# 2892   -0.028504   -0.065107  0.007090   -0.083784    0.016776     -0.007505
# 2893   -0.032871   -0.044621  0.013507    0.026242    0.015614     -0.009452
# 2894   -0.034445   -0.029206 -0.088027   -0.235086    0.014701     -0.017176
#
# [2895 rows x 9 columns]

# %%
## Export to CSV
clean_df.to_csv("output/suicide_roc.csv", index=False)
