# %%
## Dependencies
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## Suicide Rate of Change (pct_change)

# %%
## Set input file
filename = 'suicide_data.csv'
path = os.path.join('output', filename)

# %%
## Load CSV as DataFrame
df = pd.read_csv(path, low_memory=False)

# %%
df.head()
# Out:
#        country  year      country_year  alcohol_consumption  \
# 0  Afghanistan  1990  Afghanistan-1990                  0.0
# 1  Afghanistan  1991  Afghanistan-1991                  0.0
# 2  Afghanistan  1992  Afghanistan-1992                  0.0
# 3  Afghanistan  1993  Afghanistan-1993                  0.0
# 4  Afghanistan  1994  Afghanistan-1994                  0.0
#
#    suicide_rate_owid  mental_substance_disorders  life_expectancy  birth_rate  \
# 0          10.318504                   17.553463           50.331      48.880
# 1          10.327010                   17.837032           50.999      48.763
# 2          10.271411                   18.092542           51.641      48.709
# 3          10.376123                   18.294931           52.256      48.717
# 4          10.575915                   18.428908           52.842      48.770
#
#    death_rate  gdp  health_pct  population  unemployment
# 0      15.241  NaN         NaN  12412311.0           NaN
# 1      14.783  NaN         NaN  13299016.0         11.38
# 2      14.362  NaN         NaN  14485543.0         11.46
# 3      13.974  NaN         NaN  15816601.0         11.61
# 4      13.616  NaN         NaN  17075728.0         11.65

# %%
## Number of Countries & Shape
print("Countries:", df['country'].nunique())
print("Shape:", df.shape)
# Out:
# Countries: 164
# Shape: (4770, 13)

# %%
## Explore data
df.dtypes
# Out:
# country                        object
# year                            int64
# country_year                   object
# alcohol_consumption           float64
# suicide_rate_owid             float64
# mental_substance_disorders    float64
# life_expectancy               float64
# birth_rate                    float64
# death_rate                    float64
# gdp                           float64
# health_pct                    float64
# population                    float64
# unemployment                  float64
# dtype: object

# %%
## Drop NaN
df = df.dropna()

## Number of Countries & Shape
print("Countries:", df['country'].nunique())
print("Shape:", df.shape)
# Out:
# Countries: 156
# Shape: (2948, 13)

# %%
## Drop Zeros
zero_loc = (df != 0).any(axis=1)
# zero_loc.value_counts()

df = df.loc[zero_loc]

## Number of Countries & Shape
print("Countries:", df['country'].nunique())
print("Shape:", df.shape)
# Out:
# Countries: 156
# Shape: (2948, 13)

# %%
df = df.sort_values(by=['country', 'year'])
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#        country  year      country_year  alcohol_consumption  \
# 0  Afghanistan  2005  Afghanistan-2005                0.009
# 1  Afghanistan  2006  Afghanistan-2006                0.011
# 2  Afghanistan  2007  Afghanistan-2007                0.009
# 3  Afghanistan  2008  Afghanistan-2008                0.018
# 4  Afghanistan  2009  Afghanistan-2009                0.010
#
#    suicide_rate_owid  mental_substance_disorders  life_expectancy  birth_rate  \
# 0          10.655626                   17.647911           58.290      44.723
# 1          10.538475                   17.539914           58.826      43.870
# 2          10.391129                   17.444318           59.375      42.944
# 3          10.219154                   17.357110           59.930      41.949
# 4          10.036657                   17.275369           60.484      40.903
#
#    death_rate         gdp  health_pct  population  unemployment
# 0      10.003  242.031313    9.948290  25654274.0         11.52
# 1       9.645  263.733602   10.622766  26433058.0         11.34
# 2       9.287  359.693158    9.904675  27100542.0         11.18
# 3       8.932  364.660679   10.256495  27722281.0         11.11
# 4       8.584  438.076142    9.818487  28394806.0         11.46

# %%
df.columns
# Out:
# Index(['country', 'year', 'country_year', 'alcohol_consumption',
#        'suicide_rate_owid', 'mental_substance_disorders', 'life_expectancy',
#        'birth_rate', 'death_rate', 'gdp', 'health_pct', 'population',
#        'unemployment'],
#       dtype='object')

# %%
## Select columns with data (target & features)
data_cols = ['suicide_rate_owid',
             'alcohol_consumption',
             'mental_substance_disorders',
             'life_expectancy',
             'birth_rate',
             'death_rate',
             'gdp',
             'health_pct',
             'population',
             'unemployment']

# %% [markdown]
# ## Pct_change by country

# %%
country_list = df['country'].unique()
len(country_list)
# Out:
# 156

# %%
## Create global DataFrame
roc_df = pd.DataFrame(columns=data_cols)

## ROC by country
for country in country_list:
    country_df = df.loc[df['country'] == country]
    country_roc = country_df[data_cols].pct_change().dropna()
    
    ## Append to global DataFrame
    roc_df = roc_df.append(country_roc, ignore_index=True)

# %%
## Global year-to-year rate of change (%)
roc_df
# Out:
#       suicide_rate_owid  alcohol_consumption  mental_substance_disorders  \
# 0             -0.010994             0.222222                   -0.006120
# 1             -0.013982            -0.181818                   -0.005450
# 2             -0.016550             1.000000                   -0.004999
# 3             -0.017858            -0.444444                   -0.004709
# 4             -0.016068             0.000000                   -0.004163
# ...                 ...                  ...                         ...
# 2577          -0.033555             0.000000                    0.000965
# 2578          -0.026644             0.200000                    0.001184
# 2579          -0.014797             0.000000                    0.001209
# 2580          -0.013144            -0.166667                    0.001584
# 2581          -0.016685             0.000000                    0.001161
#
#       life_expectancy  birth_rate  death_rate       gdp  health_pct  \
# 0            0.009195   -0.019073   -0.035789  0.089667    0.067798
# 1            0.009333   -0.021108   -0.037118  0.363850   -0.067599
# 2            0.009347   -0.023170   -0.038225  0.013810    0.035521
# 3            0.009244   -0.024935   -0.038961  0.201325   -0.042705
# 4            0.008994   -0.026257   -0.038910  0.240202   -0.127190
# ...               ...         ...         ...       ...         ...
# 2577         0.033889   -0.014438   -0.094206  0.095811    0.027723
# 2578         0.026592   -0.022087   -0.082847  0.003425    0.143932
# 2579         0.019243   -0.028504   -0.065107  0.007090   -0.083784
# 2580         0.012766   -0.032871   -0.044621  0.013507    0.026242
# 2581         0.008591   -0.034445   -0.029206 -0.088027   -0.235086
#
#       population  unemployment
# 0       0.030357     -0.015625
# 1       0.025252     -0.014109
# 2       0.022942     -0.006261
# 3       0.024259      0.031503
# 4       0.027847      0.005236
# ...          ...           ...
# 2577    0.017936      0.000000
# 2578    0.017702     -0.009294
# 2579    0.016776     -0.007505
# 2580    0.015614     -0.009452
# 2581    0.014701     -0.017176
#
# [2582 rows x 10 columns]

# %%
## Shape & Summary
print("Shape:", roc_df.shape)
roc_df.describe()
# Out:
# Shape: (2582, 10)
#        suicide_rate_owid  alcohol_consumption  mental_substance_disorders  \
# count        2582.000000          2582.000000                 2582.000000
# mean           -0.009456                  inf                   -0.000634
# std             0.029681                  NaN                    0.001737
# min            -0.169668            -1.000000                   -0.011381
# 25%            -0.022097            -0.213955                   -0.001274
# 50%            -0.006832             0.000000                   -0.000223
# 75%             0.001219             0.066667                    0.000232
# max             0.413126                  inf                    0.007115
#
#        life_expectancy   birth_rate   death_rate          gdp   health_pct  \
# count      2582.000000  2582.000000  2582.000000  2582.000000  2582.000000
# mean          0.004933    -0.004564    -0.006419     0.069438     0.014200
# std           0.006247     0.105245     0.079596     0.163298     0.107539
# min          -0.035607    -0.600840    -0.480612    -0.640223    -0.443989
# 25%           0.001784    -0.017733    -0.023389     0.000000    -0.028865
# 50%           0.003471    -0.010316    -0.004589     0.051484     0.000587
# 75%           0.006495     0.000000     0.003588     0.131798     0.045010
# max           0.069977     1.469579     0.932367     2.260946     1.349113
#
#         population  unemployment
# count  2582.000000   2582.000000
# mean      0.035627      0.005652
# std       0.333655      0.194831
# min      -0.819465     -0.702970
# 25%       0.002863     -0.050592
# 50%       0.012823     -0.003123
# 75%       0.024034      0.030590
# max       4.544366      5.812500

# %%
## Remove infinite values
roc_df.replace([np.inf, -np.inf], np.nan, inplace=True)
clean_df = roc_df.dropna()
clean_df
# Out:
#       suicide_rate_owid  alcohol_consumption  mental_substance_disorders  \
# 0             -0.010994             0.222222                   -0.006120
# 1             -0.013982            -0.181818                   -0.005450
# 2             -0.016550             1.000000                   -0.004999
# 3             -0.017858            -0.444444                   -0.004709
# 4             -0.016068             0.000000                   -0.004163
# ...                 ...                  ...                         ...
# 2577          -0.033555             0.000000                    0.000965
# 2578          -0.026644             0.200000                    0.001184
# 2579          -0.014797             0.000000                    0.001209
# 2580          -0.013144            -0.166667                    0.001584
# 2581          -0.016685             0.000000                    0.001161
#
#       life_expectancy  birth_rate  death_rate       gdp  health_pct  \
# 0            0.009195   -0.019073   -0.035789  0.089667    0.067798
# 1            0.009333   -0.021108   -0.037118  0.363850   -0.067599
# 2            0.009347   -0.023170   -0.038225  0.013810    0.035521
# 3            0.009244   -0.024935   -0.038961  0.201325   -0.042705
# 4            0.008994   -0.026257   -0.038910  0.240202   -0.127190
# ...               ...         ...         ...       ...         ...
# 2577         0.033889   -0.014438   -0.094206  0.095811    0.027723
# 2578         0.026592   -0.022087   -0.082847  0.003425    0.143932
# 2579         0.019243   -0.028504   -0.065107  0.007090   -0.083784
# 2580         0.012766   -0.032871   -0.044621  0.013507    0.026242
# 2581         0.008591   -0.034445   -0.029206 -0.088027   -0.235086
#
#       population  unemployment
# 0       0.030357     -0.015625
# 1       0.025252     -0.014109
# 2       0.022942     -0.006261
# 3       0.024259      0.031503
# 4       0.027847      0.005236
# ...          ...           ...
# 2577    0.017936      0.000000
# 2578    0.017702     -0.009294
# 2579    0.016776     -0.007505
# 2580    0.015614     -0.009452
# 2581    0.014701     -0.017176
#
# [2498 rows x 10 columns]

# %%
## Export to CSV
clean_df.to_csv("output/suicide_roc.csv", index=False)
