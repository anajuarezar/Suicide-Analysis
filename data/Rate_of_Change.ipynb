# %%
## Dependencies
import os
import pandas as pd

# %% [markdown]
# ## Suicide Rate of Change (pct_change)

# %%
## Set input file
filename = 'extract_owid_and_wb.csv'
path = os.path.join('clean', filename)

# %%
## Load CSV as DataFrame
df = pd.read_csv(path, low_memory=False)

# %%
df.head()
# Out:
#        country  year      country_code  suicide_rate_owid  \
# 0  Afghanistan  1990  Afghanistan-1990          10.318504
# 1  Afghanistan  1991  Afghanistan-1991          10.327010
# 2  Afghanistan  1992  Afghanistan-1992          10.271411
# 3  Afghanistan  1993  Afghanistan-1993          10.376123
# 4  Afghanistan  1994  Afghanistan-1994          10.575915
#
#    mental_substance_disorders  life_expectancy  birth_rate  death_rate  gdp  \
# 0                   17.553463           50.331      48.880      15.241  NaN
# 1                   17.837032           50.999      48.763      14.783  NaN
# 2                   18.092542           51.641      48.709      14.362  NaN
# 3                   18.294931           52.256      48.717      13.974  NaN
# 4                   18.428908           52.842      48.770      13.616  NaN
#
#    health_pct  population  unemployment
# 0         NaN  12412311.0           NaN
# 1         NaN  13299016.0         11.38
# 2         NaN  14485543.0         11.46
# 3         NaN  15816601.0         11.61
# 4         NaN  17075728.0         11.65

# %%
## Number of Countries & Shape
print("Countries:", df['country'].nunique())
print("Shape:", df.shape)
# Out:
# Countries: 172
# Shape: (4748, 12)

# %%
## Explore data
df.dtypes
# Out:
# country                        object
# year                            int64
# country_code                   object
# suicide_rate_owid             float64
# mental_substance_disorders    float64
# life_expectancy               float64
# birth_rate                    float64
# death_rate                    float64
# gdp                           float64
# health_pct                    float64
# population                    float64
# unemployment                  float64
# dtype: object

# %%
## Drop NaN
df = df.dropna()

## Number of Countries & Shape
print("Countries:", df['country'].nunique())
print("Shape:", df.shape)
# Out:
# Countries: 159
# Shape: (2834, 12)

# %%
## Drop Zeros
zero_loc = (df != 0).any(axis=1)
# zero_loc.value_counts()

df = df.loc[zero_loc]

## Number of Countries & Shape
print("Countries:", df['country'].nunique())
print("Shape:", df.shape)
# Out:
# Countries: 159
# Shape: (2834, 12)

# %%
df = df.sort_values(by=['country', 'year'])
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#        country  year      country_code  suicide_rate_owid  \
# 0  Afghanistan  2002  Afghanistan-2002          11.054472
# 1  Afghanistan  2003  Afghanistan-2003          10.931093
# 2  Afghanistan  2004  Afghanistan-2004          10.839790
# 3  Afghanistan  2005  Afghanistan-2005          10.655626
# 4  Afghanistan  2006  Afghanistan-2006          10.538475
#
#    mental_substance_disorders  life_expectancy  birth_rate  death_rate  \
# 0                   18.137951           56.784      46.901      11.048
# 1                   17.958849           57.271      46.231      10.704
# 2                   17.788825           57.772      45.507      10.356
# 3                   17.647911           58.290      44.723      10.003
# 4                   17.539914           58.826      43.870       9.645
#
#           gdp  health_pct  population  unemployment
# 0  179.426579    9.443390  22600774.0         11.68
# 1  190.683814    8.941258  23680871.0         11.68
# 2  211.382074    9.808474  24726689.0         11.61
# 3  242.031313    9.948290  25654274.0         11.52
# 4  263.733602   10.622766  26433058.0         11.34

# %%
df.columns
# Out:
# Index(['country', 'year', 'country_code', 'suicide_rate_owid',
#        'mental_substance_disorders', 'life_expectancy', 'birth_rate',
#        'death_rate', 'gdp', 'health_pct', 'population', 'unemployment'],
#       dtype='object')

# %%
## Select columns with data (target & features)
data_cols = ['suicide_rate_owid',
             'mental_substance_disorders',
             'life_expectancy',
             'birth_rate',
             'death_rate',
             'gdp',
             'population',
             'unemployment',
             'health_pct']

# %% [markdown]
# ## Pct_change by country

# %%
country_list = df['country'].unique()
len(country_list)
# Out:
# 159

# %%
## Create empty DataFrame
roc_df = pd.DataFrame(columns=data_cols)

## ROC by country
for country in country_list:
    country_df = df.loc[df['country'] == country]
    country_roc = country_df[data_cols].pct_change().dropna()
    roc_df = roc_df.append(country_roc, ignore_index=True)

# %%
roc_df
# Out:
#       suicide_rate_owid  mental_substance_disorders  life_expectancy  \
# 0             -0.011161                   -0.009874         0.008576
# 1             -0.008353                   -0.009467         0.008748
# 2             -0.016990                   -0.007921         0.008966
# 3             -0.010994                   -0.006120         0.009195
# 4             -0.013982                   -0.005450         0.009333
# ...                 ...                         ...              ...
# 2670          -0.033555                    0.000965         0.033889
# 2671          -0.026644                    0.001184         0.026592
# 2672          -0.014797                    0.001209         0.019243
# 2673          -0.013144                    0.001584         0.012766
# 2674          -0.016685                    0.001161         0.008591
#
#       birth_rate  death_rate       gdp  population  unemployment  health_pct
# 0      -0.014285   -0.031137  0.062740    0.047790      0.000000   -0.053173
# 1      -0.015660   -0.032511  0.108548    0.044163     -0.005993    0.096990
# 2      -0.017228   -0.034087  0.144995    0.037514     -0.007752    0.014255
# 3      -0.019073   -0.035789  0.089667    0.030357     -0.015625    0.067798
# 4      -0.021108   -0.037118  0.363850    0.025252     -0.014109   -0.067599
# ...          ...         ...       ...         ...           ...         ...
# 2670   -0.014438   -0.094206  0.095811    0.017936      0.000000    0.027723
# 2671   -0.022087   -0.082847  0.003425    0.017702     -0.009294    0.143932
# 2672   -0.028504   -0.065107  0.007090    0.016776     -0.007505   -0.083784
# 2673   -0.032871   -0.044621  0.013507    0.015614     -0.009452    0.026242
# 2674   -0.034445   -0.029206 -0.088027    0.014701     -0.017176   -0.235086
#
# [2675 rows x 9 columns]

# %%
roc_df.describe()
# Out:
#        suicide_rate_owid  mental_substance_disorders  life_expectancy  \
# count        2675.000000                 2675.000000      2675.000000
# mean           -0.010692                   -0.000709         0.005471
# std             0.029556                    0.001799         0.006091
# min            -0.169668                   -0.010424        -0.035607
# 25%            -0.023397                   -0.001476         0.002238
# 50%            -0.009074                   -0.000387         0.003973
# 75%             0.001347                    0.000308         0.007101
# max             0.413126                    0.007115         0.044550
#
#         birth_rate   death_rate          gdp   population  unemployment  \
# count  2675.000000  2675.000000  2675.000000  2675.000000   2675.000000
# mean     -0.009637    -0.010181     0.072694     0.015518      0.004607
# std       0.021118     0.024079     0.136647     0.016554      0.189547
# min      -0.138686    -0.133333    -0.640223    -0.037746     -0.805556
# 25%      -0.018552    -0.024478     0.006146     0.005234     -0.059596
# 50%      -0.011367    -0.009213     0.063959     0.013566     -0.007792
# 75%      -0.003252     0.003859     0.138676     0.024548      0.037356
# max       0.144928     0.098361     1.884354     0.191392      5.812500
#
#         health_pct
# count  2675.000000
# mean      0.015221
# std       0.108067
# min      -0.443989
# 25%      -0.030245
# 50%       0.006485
# 75%       0.048239
# max       1.478131

# %%
roc_df = pd.DataFrame(columns=data_cols)
roc_df
# Out:
# Empty DataFrame
# Columns: [suicide_rate_owid, mental_substance_disorders, life_expectancy, birth_rate, death_rate, gdp, population, unemployment, health_pct]
# Index: []

# %%
country = 'Afghanistan'
country_df = df.loc[df['country'] == country]
country_roc = country_df[data_cols].pct_change().dropna()
country_roc
# Out:
#     suicide_rate_owid  mental_substance_disorders  life_expectancy  \
# 1           -0.011161                   -0.009874         0.008576
# 2           -0.008353                   -0.009467         0.008748
# 3           -0.016990                   -0.007921         0.008966
# 4           -0.010994                   -0.006120         0.009195
# 5           -0.013982                   -0.005450         0.009333
# 6           -0.016550                   -0.004999         0.009347
# 7           -0.017858                   -0.004709         0.009244
# 8           -0.016068                   -0.004163         0.008994
# 9           -0.015546                   -0.003903         0.008603
# 10          -0.015554                   -0.003692         0.008139
# 11          -0.012851                   -0.003241         0.007590
# 12          -0.010683                   -0.003675         0.007053
# 13          -0.002955                   -0.002693         0.006527
# 14          -0.007245                   -0.002431         0.006091
# 15          -0.006813                   -0.002226         0.005756
#
#     birth_rate  death_rate       gdp  population  unemployment  health_pct
# 1    -0.014285   -0.031137  0.062740    0.047790      0.000000   -0.053173
# 2    -0.015660   -0.032511  0.108548    0.044163     -0.005993    0.096990
# 3    -0.017228   -0.034087  0.144995    0.037514     -0.007752    0.014255
# 4    -0.019073   -0.035789  0.089667    0.030357     -0.015625    0.067798
# 5    -0.021108   -0.037118  0.363850    0.025252     -0.014109   -0.067599
# 6    -0.023170   -0.038225  0.013810    0.022942     -0.006261    0.035521
# 7    -0.024935   -0.038961  0.201325    0.024259      0.031503   -0.042705
# 8    -0.026257   -0.038910  0.240202    0.027847      0.005236   -0.127190
# 9    -0.027091   -0.038061  0.088091    0.031930     -0.000868   -0.000906
# 10   -0.027355   -0.036668  0.085778    0.034663      0.000869   -0.077639
# 11   -0.027063   -0.034663 -0.007332    0.035564      0.001736    0.115079
# 12   -0.026289   -0.032385 -0.036582    0.034125     -0.007799    0.082094
# 13   -0.025122   -0.029688 -0.057652    0.031249     -0.005240    0.060497
# 14   -0.023787   -0.026988 -0.119707    0.028170     -0.007024    0.084772
# 15   -0.022660   -0.024770  0.020951    0.025806     -0.011494    0.074369

# %%
roc_df = roc_df.concat(country_roc, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-511fdecb9694> in <module>
# ----> 1 roc_df.concat(country_roc, ignore_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
roc_df
# Out:
# Empty DataFrame
# Columns: [suicide_rate_owid, mental_substance_disorders, life_expectancy, birth_rate, death_rate, gdp, population, unemployment, health_pct]
# Index: []

# %%
## Compute year-to-year rate of change (%)
roc_df = df[data_cols].pct_change().dropna()
roc_df
# Out:
#       suicide_rate_owid  mental_substance_disorders  life_expectancy  \
# 1             -0.011161                   -0.009874         0.008576
# 2             -0.008353                   -0.009467         0.008748
# 3             -0.016990                   -0.007921         0.008966
# 4             -0.010994                   -0.006120         0.009195
# 5             -0.013982                   -0.005450         0.009333
# ...                 ...                         ...              ...
# 2811          -0.033555                    0.000965         0.033889
# 2812          -0.026644                    0.001184         0.026592
# 2813          -0.014797                    0.001209         0.019243
# 2814          -0.013144                    0.001584         0.012766
# 2815          -0.016685                    0.001161         0.008591
#
#       birth_rate  death_rate       gdp  population  unemployment  health_pct
# 1      -0.014285   -0.031137  0.062740    0.047790      0.000000   -0.053173
# 2      -0.015660   -0.032511  0.108548    0.044163     -0.005993    0.096990
# 3      -0.017228   -0.034087  0.144995    0.037514     -0.007752    0.014255
# 4      -0.019073   -0.035789  0.089667    0.030357     -0.015625    0.067798
# 5      -0.021108   -0.037118  0.363850    0.025252     -0.014109   -0.067599
# ...          ...         ...       ...         ...           ...         ...
# 2811   -0.014438   -0.094206  0.095811    0.017936      0.000000    0.027723
# 2812   -0.022087   -0.082847  0.003425    0.017702     -0.009294    0.143932
# 2813   -0.028504   -0.065107  0.007090    0.016776     -0.007505   -0.083784
# 2814   -0.032871   -0.044621  0.013507    0.015614     -0.009452    0.026242
# 2815   -0.034445   -0.029206 -0.088027    0.014701     -0.017176   -0.235086
#
# [2815 rows x 9 columns]

# %%
## Shape & Summary
print("Shape:", roc_df.shape)
roc_df.describe()
# Out:
# Shape: (2815, 9)
#        suicide_rate_owid  mental_substance_disorders  life_expectancy  \
# count        2815.000000                 2815.000000      2815.000000
# mean            0.028349                    0.000890         0.001252
# std             0.429687                    0.047205         0.045777
# min            -0.813706                   -0.417155        -0.477873
# 25%            -0.023841                   -0.001542         0.002090
# 50%            -0.008764                   -0.000382         0.003853
# 75%             0.002898                    0.000352         0.007128
# max            10.278132                    0.707883         0.446353
#
#         birth_rate   death_rate          gdp   population  unemployment  \
# count  2815.000000  2815.000000  2815.000000  2815.000000   2815.000000
# mean      0.017843     0.017424     0.127778     1.548401      0.096066
# std       0.267122     0.311297     1.237604    58.365208      1.686726
# min      -0.799728    -0.871103    -0.998339    -0.998613     -0.935738
# 25%      -0.018868    -0.024926    -0.002425     0.004939     -0.063785
# 50%      -0.011111    -0.008547     0.060130     0.013589     -0.007557
# 75%      -0.002077     0.005685     0.138901     0.025241      0.042288
# max       4.139222     8.751925    46.763788  3075.807070     53.285714
#
#         health_pct
# count  2815.000000
# mean      0.014358
# std       0.176845
# min      -0.798837
# 25%      -0.034625
# 50%       0.005553
# 75%       0.049307
# max       2.262684

# %%
roc_df.to_csv("output/suicide_roc.csv", index=False)
